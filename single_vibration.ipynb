# %%
# !pip install matplotlib
# Out:
# ...
#      |████████████████████████████████| 11.3 MB 4.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 4.3 MB 38.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 930 kB 90.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.2 MB 19.8 MB/s eta 0:00:01
# ...
#   WARNING: The scripts fonttools, pyftmerge, pyftsubset and ttx are installed in '/home/toson/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("test.csv", header=None).set_index(0)

# %%
df = df.loc[:,1]
df = df.drop("time")
df = df.astype(float)
df
# Out:
# 0
# 0                    0.994975
# 0.01                 0.989900
# 0.02                 0.984776
# 0.03                 0.979603
# 0.04                 0.974380
#                        ...
# 99.95               -0.703662
# 99.96000000000001   -0.710732
# 99.97               -0.717767
# 99.98               -0.724767
# 99.99000000000001   -0.731729
# Name: 1, Length: 10000, dtype: float64

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='0'>
