# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("test2.csv", header=None).set_index(0)
df = df.drop("time")
df = df.drop([1,3], axis=1)
df = df.rename(columns={0: "time", 2: "u_1", 4:"u_2"})
df = df.astype(float)
df["u_2"] = df["u_2"] + 0.5
df
# Out:
#                         u_1       u_2
# 0
# 0                  0.200000  0.899985
# 0.01               0.200000  0.899940
# 0.02               0.200000  0.899865
# 0.03               0.200000  0.899760
# 0.04               0.200000  0.899625
# ...                     ...       ...
# 99.95              0.100566  0.401499
# 99.96000000000001  0.098555  0.399267
# 99.97              0.096530  0.397050
# 99.98              0.094489  0.394848
# 99.99000000000001  0.092434  0.392661
#
# [10000 rows x 2 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='0'>
